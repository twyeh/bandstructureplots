# %% [markdown]
# <a href="https://colab.research.google.com/github/twyeh/bandstructureplots/blob/master/ASE_examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install --upgrade ase[test]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 47.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 2.3 MB/s eta 0:00:00
# ...

# %%
import bs

# %%
from ase import Atoms

atoms = Atoms('N2', positions=[[0, 0, -1], [0, 0, 1]])
# print(atoms.cell.get_bravais_lattice())

# %%
from ase.visualize import view
view(atoms)
# Out:
# <Popen: returncode: None args: ['/usr/bin/python3', '-m', 'ase', 'gui', '-']>
